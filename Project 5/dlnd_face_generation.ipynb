# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# C:\Program Files\Anaconda3\envs\tensorflow-cpu\lib\site-packages\ipykernel\__main__.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """

    # TODO: Implement Function
    real_input_images = tf.placeholder(tf.float32, [None, image_width, image_height, image_channels], name='real_input_images')
    # Goes into the generator
    z_input = tf.placeholder(tf.float32, [None, z_dim], name='input_z')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    
    return real_input_images, z_input, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def leaky_relu(x, alpha=0.2):
    return tf.maximum(alpha * x, x)

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """

    
    with tf.variable_scope('discriminator', reuse=reuse):

        #print(images)
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        x1 = leaky_relu(x1)
            
        x2 = tf.layers.conv2d(x1, 128, 5, strides=1, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=True)
        bn2 = leaky_relu(bn2)
        
        x3 = tf.layers.conv2d(bn2, 256, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=True)
        bn3 = leaky_relu(bn3)
        
        x4 = tf.layers.conv2d(x3, 512, 5, strides=1, padding='same')
        bn4 = tf.layers.batch_normalization(x4, training=True)
        bn4 = leaky_relu(bn4)
        
        
        # Dropout
        bn4 = tf.nn.dropout(bn4, 0.5)
        
       
        # Flatten it
        flat = tf.reshape(bn4, (-1, 7*7*512))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)
        
        return out, logits
    
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):

    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    
    # TODO: Implement Function
    '''
    reuse and is_train are interconnected. 
    They are opposite to each other. reuse = not is_train
    '''
    with tf.variable_scope('generator', reuse= not is_train):        
        # First fully connected layer
        x1 = tf.layers.dense(z, 7*7*512)
     
    
        
        # Reshape it to start the convolutional stack
        x1 = tf.reshape(x1, (-1, 7, 7, 512))
        x1 = tf.layers.batch_normalization(x1, training = is_train)
        x1 = leaky_relu(x1)
      
    
        x2 = tf.layers.conv2d_transpose(x1,256, 5, strides=2, padding='same')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = leaky_relu(x2)

 
        
        x3 = tf.layers.conv2d_transpose(x2, 128, 5, strides=1, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = leaky_relu(x3)

        x4 = tf.layers.conv2d_transpose(x3, 64, 5, strides=2, padding='same')
        x4 = tf.layers.batch_normalization(x4, training=is_train)
        x4 = leaky_relu(x4)
        
        # Dropout
        x4 = tf.nn.dropout(x4, 0.5)
      
        
        # Output layer
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 5, strides=2, padding='same')

        out = tf.tanh(logits)
        return out

   
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
import numpy as np

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """

    # TODO: Implement Function
    
    g_model = generator( input_z, out_channel_dim)
    
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    
    d_loss_real = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_logits_real) * np.random.uniform(0.7, 1.2)))
    #d_loss_fake = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_logits_real)))
    d_loss_fake = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_logits_fake)))

    #d_loss_real = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_model_real)))
    #d_loss_fake = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean( tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function

    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    : param epoch_count: Number of epochs
    : param batch_size: Batch Size
    : param z_dim: Z dimension
    : param learning_rate: Learning Rate
    : param beta1: The exponential decay rate for the 1st moment in the optimizer
    : param get_batches: Function to get batches
    : param data_shape: Shape of the data
    : param data_image_mode: The image mode to use for images ("RGB" or "L")
    """

    # TODO: Build Model
    # tf.reset_default_graph()
    real_input_images, input_z, learning_r = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)
    
    d_loss, g_loss = model_loss(real_input_images, input_z, data_shape[3])
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_r, beta1)

    steps = 0
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
         
            for batch_images in get_batches(batch_size):
                steps += 1
                
                batch_images = batch_images*2
                
                
                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                
                # Run optimizers
                _ = sess.run(d_train_opt, feed_dict={real_input_images:batch_images, input_z:batch_z, learning_r : learning_rate })  
                _ = sess.run(g_train_opt, feed_dict={real_input_images:batch_images, input_z: batch_z, learning_r : learning_rate})
               
           
                if steps % 2 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, real_input_images: batch_images})
                    #train_loss_g = g_loss.eval({input_z: batch_z})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))

            show_generator_output(sess, n_images = 25, input_z = input_z, out_channel_dim = data_shape[3], image_mode = data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 16
z_dim = 100
learning_rate = 0.0004
beta1 = 0.2


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2
mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 2.1357... Generator Loss: 0.0282
# Epoch 1/2... Discriminator Loss: 19.8912... Generator Loss: 0.0000
# Epoch 1/2... Discriminator Loss: -4.6271... Generator Loss: 4.5623
# Epoch 1/2... Discriminator Loss: -4.1616... Generator Loss: 19.2976
# Epoch 1/2... Discriminator Loss: -7.4271... Generator Loss: 16.0784
# Epoch 1/2... Discriminator Loss: 9.3437... Generator Loss: 0.0000
# Epoch 1/2... Discriminator Loss: -8.4244... Generator Loss: 13.6405
# Epoch 1/2... Discriminator Loss: 23.2743... Generator Loss: 0.0000
# Epoch 1/2... Discriminator Loss: -8.3200... Generator Loss: 21.3604
# Epoch 1/2... Discriminator Loss: -11.4977... Generator Loss: 18.0761
# Epoch 1/2... Discriminator Loss: -14.1074... Generator Loss: 8.7608
# Epoch 1/2... Discriminator Loss: 9.7800... Generator Loss: 1.0925
# Epoch 1/2... Discriminator Loss: -2.4624... Generator Loss: 4.1918
# Epoch 1/2... Discriminator Loss: 3.5947... Generator Loss: 0.0033
# Epoch 1/2... Discriminator Loss: -2.5823... Generator Loss: 3.0546
# Epoch 1/2... Discriminator Loss: -1.7610... Generator Loss: 1.1201
# Epoch 1/2... Discriminator Loss: -4.5499... Generator Loss: 2.2316
# Epoch 1/2... Discriminator Loss: -7.5046... Generator Loss: 1.1297
# Epoch 1/2... Discriminator Loss: -5.4210... Generator Loss: 3.8864
# Epoch 1/2... Discriminator Loss: -4.9617... Generator Loss: 8.7595
# Epoch 1/2... Discriminator Loss: -8.6037... Generator Loss: 5.5762
# Epoch 1/2... Discriminator Loss: 7.6584... Generator Loss: 0.0035
# Epoch 1/2... Discriminator Loss: -4.0385... Generator Loss: 12.5236
# Epoch 1/2... Discriminator Loss: 25.8036... Generator Loss: 0.0000
# Epoch 1/2... Discriminator Loss: 2.8182... Generator Loss: 1.0948
# Epoch 1/2... Discriminator Loss: -1.6068... Generator Loss: 2.7053
# Epoch 1/2... Discriminator Loss: 3.3239... Generator Loss: 0.7775
# Epoch 1/2... Discriminator Loss: 18.0859... Generator Loss: 0.0001
# Epoch 1/2... Discriminator Loss: -1.0622... Generator Loss: 5.6516
# Epoch 1/2... Discriminator Loss: -1.8358... Generator Loss: 1.8584
# Epoch 1/2... Discriminator Loss: -0.9605... Generator Loss: 1.5329
# Epoch 1/2... Discriminator Loss: -2.5931... Generator Loss: 4.1552
# Epoch 1/2... Discriminator Loss: 4.3978... Generator Loss: 8.0714
# Epoch 1/2... Discriminator Loss: 1.4574... Generator Loss: 0.4809
# Epoch 1/2... Discriminator Loss: -0.3364... Generator Loss: 1.6072
# Epoch 1/2... Discriminator Loss: 0.7112... Generator Loss: 1.5950
# Epoch 1/2... Discriminator Loss: 1.0381... Generator Loss: 0.4684
# Epoch 1/2... Discriminator Loss: 6.5596... Generator Loss: 0.1121
# Epoch 1/2... Discriminator Loss: 0.5095... Generator Loss: 0.8736
# Epoch 1/2... Discriminator Loss: 1.4478... Generator Loss: 0.3484
# Epoch 1/2... Discriminator Loss: 0.9004... Generator Loss: 0.7294
# Epoch 1/2... Discriminator Loss: 3.3328... Generator Loss: 0.4056
# Epoch 1/2... Discriminator Loss: -0.3790... Generator Loss: 2.6292
# Epoch 1/2... Discriminator Loss: 1.9969... Generator Loss: 0.4657
# Epoch 1/2... Discriminator Loss: -1.3081... Generator Loss: 3.7660
# Epoch 1/2... Discriminator Loss: 3.1716... Generator Loss: 5.9211
# Epoch 1/2... Discriminator Loss: 0.0505... Generator Loss: 2.1488
# Epoch 1/2... Discriminator Loss: 1.6861... Generator Loss: 0.7465
# Epoch 1/2... Discriminator Loss: 3.3036... Generator Loss: 6.0032
# Epoch 1/2... Discriminator Loss: -0.2433... Generator Loss: 5.1719
# Epoch 1/2... Discriminator Loss: -0.3346... Generator Loss: 1.2093
# Epoch 1/2... Discriminator Loss: 1.9881... Generator Loss: 0.5897
# Epoch 1/2... Discriminator Loss: -0.6210... Generator Loss: 1.4662
# Epoch 1/2... Discriminator Loss: -0.4840... Generator Loss: 1.7560
# Epoch 1/2... Discriminator Loss: 3.5548... Generator Loss: 0.0090
# Epoch 1/2... Discriminator Loss: 0.2788... Generator Loss: 6.8280
# Epoch 1/2... Discriminator Loss: 1.8680... Generator Loss: 6.4676
# Epoch 1/2... Discriminator Loss: -0.4229... Generator Loss: 3.0483
# Epoch 1/2... Discriminator Loss: 1.4860... Generator Loss: 0.3826
# Epoch 1/2... Discriminator Loss: -0.5049... Generator Loss: 1.9991
# Epoch 1/2... Discriminator Loss: -0.1829... Generator Loss: 6.0507
# Epoch 1/2... Discriminator Loss: 0.5747... Generator Loss: 4.1461
# Epoch 1/2... Discriminator Loss: -0.8338... Generator Loss: 2.9125
# Epoch 1/2... Discriminator Loss: -1.3031... Generator Loss: 2.7433
# Epoch 1/2... Discriminator Loss: 1.1347... Generator Loss: 0.6278
# Epoch 1/2... Discriminator Loss: -1.4898... Generator Loss: 2.6620
# Epoch 1/2... Discriminator Loss: -0.6467... Generator Loss: 1.2762
# Epoch 1/2... Discriminator Loss: 0.8304... Generator Loss: 0.2010
# Epoch 1/2... Discriminator Loss: -1.3661... Generator Loss: 4.1675
# Epoch 1/2... Discriminator Loss: 1.4936... Generator Loss: 7.6529
# Epoch 1/2... Discriminator Loss: 0.0990... Generator Loss: 8.6781
# Epoch 1/2... Discriminator Loss: 0.7952... Generator Loss: 6.1069
# Epoch 1/2... Discriminator Loss: 1.8456... Generator Loss: 0.9615
# Epoch 1/2... Discriminator Loss: -0.8200... Generator Loss: 8.0810
# Epoch 1/2... Discriminator Loss: -1.2418... Generator Loss: 2.8712
# Epoch 1/2... Discriminator Loss: -1.7793... Generator Loss: 2.5253
# Epoch 1/2... Discriminator Loss: -0.3988... Generator Loss: 8.0463
# Epoch 1/2... Discriminator Loss: -0.3654... Generator Loss: 4.6934
# Epoch 1/2... Discriminator Loss: 2.6034... Generator Loss: 3.3316
# Epoch 1/2... Discriminator Loss: 0.0331... Generator Loss: 7.6297
# Epoch 1/2... Discriminator Loss: -0.2540... Generator Loss: 2.3405
# Epoch 1/2... Discriminator Loss: 1.2240... Generator Loss: 0.5119
# Epoch 1/2... Discriminator Loss: -1.1732... Generator Loss: 4.7598
# Epoch 1/2... Discriminator Loss: 0.5296... Generator Loss: 0.9970
# Epoch 1/2... Discriminator Loss: -0.8454... Generator Loss: 3.8307
# Epoch 1/2... Discriminator Loss: 0.8053... Generator Loss: 5.3996
# Epoch 1/2... Discriminator Loss: -0.2710... Generator Loss: 7.0794
# Epoch 1/2... Discriminator Loss: 2.0081... Generator Loss: 4.4595
# Epoch 1/2... Discriminator Loss: 0.0093... Generator Loss: 4.3189
# Epoch 1/2... Discriminator Loss: -0.7560... Generator Loss: 5.1079
# Epoch 1/2... Discriminator Loss: -0.9799... Generator Loss: 5.8636
# Epoch 1/2... Discriminator Loss: -0.0126... Generator Loss: 6.7479
# Epoch 1/2... Discriminator Loss: 1.7332... Generator Loss: 6.7777
# Epoch 1/2... Discriminator Loss: 0.0411... Generator Loss: 6.9969
# Epoch 1/2... Discriminator Loss: 0.2198... Generator Loss: 7.3971
# Epoch 1/2... Discriminator Loss: -0.7641... Generator Loss: 5.0599
# Epoch 1/2... Discriminator Loss: 0.2116... Generator Loss: 2.3533
# Epoch 1/2... Discriminator Loss: 0.1617... Generator Loss: 6.6732
# Epoch 1/2... Discriminator Loss: -0.7315... Generator Loss: 5.3177
# Epoch 1/2... Discriminator Loss: -1.1809... Generator Loss: 5.9842
# Epoch 1/2... Discriminator Loss: 0.6949... Generator Loss: 5.1616
# Epoch 1/2... Discriminator Loss: 1.2100... Generator Loss: 3.1209
# Epoch 1/2... Discriminator Loss: 1.8439... Generator Loss: 6.3602
# Epoch 1/2... Discriminator Loss: -0.0619... Generator Loss: 1.3115
# Epoch 1/2... Discriminator Loss: 3.6834... Generator Loss: 0.1879
# Epoch 1/2... Discriminator Loss: -0.7855... Generator Loss: 4.5777
# Epoch 1/2... Discriminator Loss: 2.8208... Generator Loss: 0.0629
# Epoch 1/2... Discriminator Loss: -0.1898... Generator Loss: 1.2970
# Epoch 1/2... Discriminator Loss: -0.8978... Generator Loss: 5.2778
# Epoch 1/2... Discriminator Loss: -1.0121... Generator Loss: 6.1368
# Epoch 1/2... Discriminator Loss: 5.4475... Generator Loss: 6.4509
# Epoch 1/2... Discriminator Loss: -0.8436... Generator Loss: 3.7206
# Epoch 1/2... Discriminator Loss: -0.1664... Generator Loss: 1.8802
# Epoch 1/2... Discriminator Loss: 0.5629... Generator Loss: 2.6384
# Epoch 1/2... Discriminator Loss: 0.3690... Generator Loss: 3.0960
# Epoch 1/2... Discriminator Loss: 0.3191... Generator Loss: 3.6926
# Epoch 1/2... Discriminator Loss: 1.2157... Generator Loss: 5.3449
# Epoch 1/2... Discriminator Loss: -0.7782... Generator Loss: 3.8730
# Epoch 1/2... Discriminator Loss: 1.8137... Generator Loss: 0.1199
# Epoch 1/2... Discriminator Loss: -0.3157... Generator Loss: 1.4868
# Epoch 1/2... Discriminator Loss: -1.1135... Generator Loss: 3.0065
# Epoch 1/2... Discriminator Loss: 5.0308... Generator Loss: 0.0060
# Epoch 1/2... Discriminator Loss: 1.4330... Generator Loss: 2.4555
# Epoch 1/2... Discriminator Loss: 2.4079... Generator Loss: 2.2649
# Epoch 1/2... Discriminator Loss: 1.1479... Generator Loss: 4.5549
# Epoch 1/2... Discriminator Loss: 1.5505... Generator Loss: 0.6449
# Epoch 1/2... Discriminator Loss: 0.0208... Generator Loss: 0.7950
# Epoch 1/2... Discriminator Loss: 1.7089... Generator Loss: 0.6204
# Epoch 1/2... Discriminator Loss: 1.5143... Generator Loss: 0.4555
# Epoch 1/2... Discriminator Loss: -0.7606... Generator Loss: 2.3829
# Epoch 1/2... Discriminator Loss: 1.0766... Generator Loss: 3.6533
# Epoch 1/2... Discriminator Loss: -0.0469... Generator Loss: 2.6242
# Epoch 1/2... Discriminator Loss: -0.3266... Generator Loss: 1.9189
# Epoch 1/2... Discriminator Loss: 5.9553... Generator Loss: 0.0059
# Epoch 1/2... Discriminator Loss: 0.5344... Generator Loss: 1.0707
# Epoch 1/2... Discriminator Loss: 1.3314... Generator Loss: 1.2910
# Epoch 1/2... Discriminator Loss: 0.3483... Generator Loss: 4.1224
# Epoch 1/2... Discriminator Loss: -0.0497... Generator Loss: 5.7115
# Epoch 1/2... Discriminator Loss: 0.5001... Generator Loss: 5.8193
# Epoch 1/2... Discriminator Loss: 0.8018... Generator Loss: 4.2758
# Epoch 1/2... Discriminator Loss: 3.1285... Generator Loss: 3.7559
# Epoch 1/2... Discriminator Loss: -0.3226... Generator Loss: 2.0321
# Epoch 1/2... Discriminator Loss: 0.4246... Generator Loss: 1.5725
# Epoch 1/2... Discriminator Loss: -0.1729... Generator Loss: 1.9613
# Epoch 1/2... Discriminator Loss: 0.1243... Generator Loss: 0.7605
# Epoch 1/2... Discriminator Loss: 0.0158... Generator Loss: 0.6570
# Epoch 1/2... Discriminator Loss: 0.4261... Generator Loss: 0.7261
# Epoch 1/2... Discriminator Loss: -0.5271... Generator Loss: 2.8337
# Epoch 1/2... Discriminator Loss: 0.9171... Generator Loss: 0.6474
# Epoch 1/2... Discriminator Loss: -0.3452... Generator Loss: 2.4515
# Epoch 1/2... Discriminator Loss: -0.3598... Generator Loss: 2.8134
# Epoch 1/2... Discriminator Loss: -0.0843... Generator Loss: 5.4513
# Epoch 1/2... Discriminator Loss: 1.8640... Generator Loss: 3.5004
# Epoch 1/2... Discriminator Loss: -0.8974... Generator Loss: 3.2061
# Epoch 1/2... Discriminator Loss: 1.6153... Generator Loss: 0.1598
# Epoch 1/2... Discriminator Loss: 0.5221... Generator Loss: 2.1467
# Epoch 1/2... Discriminator Loss: -0.8689... Generator Loss: 3.3189
# Epoch 1/2... Discriminator Loss: 1.6905... Generator Loss: 3.4588
# Epoch 1/2... Discriminator Loss: 0.4233... Generator Loss: 0.8471
# Epoch 1/2... Discriminator Loss: 1.6014... Generator Loss: 0.1506
# Epoch 1/2... Discriminator Loss: -0.2201... Generator Loss: 4.0116
# Epoch 1/2... Discriminator Loss: 0.6455... Generator Loss: 1.1831
# Epoch 1/2... Discriminator Loss: -0.1101... Generator Loss: 2.7891
# Epoch 1/2... Discriminator Loss: -0.4069... Generator Loss: 1.4963
# Epoch 1/2... Discriminator Loss: 4.6969... Generator Loss: 0.0066
# Epoch 1/2... Discriminator Loss: 0.6251... Generator Loss: 0.4713
# Epoch 1/2... Discriminator Loss: 0.4215... Generator Loss: 5.4029
# Epoch 1/2... Discriminator Loss: -0.8310... Generator Loss: 3.4361
# Epoch 1/2... Discriminator Loss: 5.4441... Generator Loss: 0.0046
# Epoch 1/2... Discriminator Loss: 0.9743... Generator Loss: 0.5899
# Epoch 1/2... Discriminator Loss: -0.1149... Generator Loss: 2.0847
# Epoch 1/2... Discriminator Loss: -0.3690... Generator Loss: 2.0162
# Epoch 1/2... Discriminator Loss: 0.4667... Generator Loss: 0.3442
# Epoch 1/2... Discriminator Loss: 2.5761... Generator Loss: 0.2171
# Epoch 1/2... Discriminator Loss: 3.5355... Generator Loss: 0.0586
# Epoch 1/2... Discriminator Loss: 0.7498... Generator Loss: 1.8484
# Epoch 1/2... Discriminator Loss: -0.4415... Generator Loss: 3.3866
# Epoch 1/2... Discriminator Loss: 6.4534... Generator Loss: 9.0489
# Epoch 1/2... Discriminator Loss: -0.6701... Generator Loss: 3.5664
# Epoch 1/2... Discriminator Loss: -0.9681... Generator Loss: 2.7936
# Epoch 1/2... Discriminator Loss: 0.7258... Generator Loss: 1.8800
# Epoch 1/2... Discriminator Loss: 0.9034... Generator Loss: 3.9045
# Epoch 1/2... Discriminator Loss: 1.7017... Generator Loss: 5.3561
# Epoch 1/2... Discriminator Loss: 0.2362... Generator Loss: 4.5021
# Epoch 1/2... Discriminator Loss: 0.4820... Generator Loss: 3.7467
# Epoch 1/2... Discriminator Loss: 1.2175... Generator Loss: 5.7106
# Epoch 1/2... Discriminator Loss: 1.1574... Generator Loss: 1.4048
# Epoch 1/2... Discriminator Loss: 4.1631... Generator Loss: 0.0426
# Epoch 1/2... Discriminator Loss: 0.2515... Generator Loss: 0.4757
# Epoch 1/2... Discriminator Loss: 0.8203... Generator Loss: 0.4652
# Epoch 1/2... Discriminator Loss: 1.0541... Generator Loss: 5.4974
# Epoch 1/2... Discriminator Loss: 0.9602... Generator Loss: 2.1820
# Epoch 1/2... Discriminator Loss: 3.9970... Generator Loss: 0.0124
# Epoch 1/2... Discriminator Loss: 2.4486... Generator Loss: 0.0990
# Epoch 1/2... Discriminator Loss: -0.3661... Generator Loss: 2.8443
# Epoch 1/2... Discriminator Loss: 2.1964... Generator Loss: 3.0222
# Epoch 1/2... Discriminator Loss: -0.0538... Generator Loss: 3.4985
# Epoch 1/2... Discriminator Loss: 0.3409... Generator Loss: 3.6106
# Epoch 1/2... Discriminator Loss: 0.5384... Generator Loss: 2.4749
# Epoch 1/2... Discriminator Loss: 1.0124... Generator Loss: 3.9245
# Epoch 1/2... Discriminator Loss: 0.3961... Generator Loss: 1.8994
# Epoch 1/2... Discriminator Loss: 0.0707... Generator Loss: 3.3664
# Epoch 1/2... Discriminator Loss: -0.1938... Generator Loss: 2.7587
# Epoch 1/2... Discriminator Loss: 0.8834... Generator Loss: 2.2791
# Epoch 1/2... Discriminator Loss: 3.5392... Generator Loss: 5.3458
# Epoch 1/2... Discriminator Loss: 0.6163... Generator Loss: 1.0024
# Epoch 1/2... Discriminator Loss: 0.8010... Generator Loss: 0.6059
# Epoch 1/2... Discriminator Loss: 3.1964... Generator Loss: 0.0379
# Epoch 1/2... Discriminator Loss: 0.3287... Generator Loss: 3.7579
# Epoch 1/2... Discriminator Loss: 1.9704... Generator Loss: 2.8065
# Epoch 1/2... Discriminator Loss: 2.1223... Generator Loss: 3.4362
# Epoch 1/2... Discriminator Loss: 3.1056... Generator Loss: 1.6818
# Epoch 1/2... Discriminator Loss: 2.2668... Generator Loss: 1.4175
# Epoch 1/2... Discriminator Loss: 0.9805... Generator Loss: 3.6384
# Epoch 1/2... Discriminator Loss: 0.5438... Generator Loss: 1.7164
# Epoch 1/2... Discriminator Loss: 1.0771... Generator Loss: 2.9461
# Epoch 1/2... Discriminator Loss: 0.6706... Generator Loss: 3.4084
# Epoch 1/2... Discriminator Loss: 1.2653... Generator Loss: 4.1211
# Epoch 1/2... Discriminator Loss: -0.3194... Generator Loss: 3.1336
# Epoch 1/2... Discriminator Loss: -0.4016... Generator Loss: 2.2101
# Epoch 1/2... Discriminator Loss: 0.5951... Generator Loss: 4.9153
# Epoch 1/2... Discriminator Loss: 2.5194... Generator Loss: 0.4742
# Epoch 1/2... Discriminator Loss: 1.9661... Generator Loss: 4.4711
# Epoch 1/2... Discriminator Loss: -0.0173... Generator Loss: 1.5153
# Epoch 1/2... Discriminator Loss: 3.9557... Generator Loss: 0.0383
# Epoch 1/2... Discriminator Loss: 1.8318... Generator Loss: 0.1395
# Epoch 1/2... Discriminator Loss: 1.0328... Generator Loss: 4.3520
# Epoch 1/2... Discriminator Loss: -0.6056... Generator Loss: 3.4876
# Epoch 1/2... Discriminator Loss: -0.6676... Generator Loss: 1.4797
# Epoch 1/2... Discriminator Loss: -0.8133... Generator Loss: 2.8362
# Epoch 1/2... Discriminator Loss: 0.2545... Generator Loss: 4.0908
# Epoch 1/2... Discriminator Loss: 0.9133... Generator Loss: 2.4192
# Epoch 1/2... Discriminator Loss: -0.2915... Generator Loss: 1.0654
# Epoch 1/2... Discriminator Loss: 1.6167... Generator Loss: 0.1973
# Epoch 1/2... Discriminator Loss: 4.1034... Generator Loss: 0.0264
# Epoch 1/2... Discriminator Loss: -0.0864... Generator Loss: 1.7896
# Epoch 1/2... Discriminator Loss: 0.6090... Generator Loss: 1.1521
# Epoch 1/2... Discriminator Loss: 1.1237... Generator Loss: 0.4416
# Epoch 1/2... Discriminator Loss: 0.7297... Generator Loss: 0.3824
# Epoch 1/2... Discriminator Loss: 1.2768... Generator Loss: 1.0885
# Epoch 1/2... Discriminator Loss: 2.1291... Generator Loss: 3.4395
# Epoch 1/2... Discriminator Loss: -0.0176... Generator Loss: 0.9529
# Epoch 1/2... Discriminator Loss: 2.2757... Generator Loss: 0.5378
# Epoch 1/2... Discriminator Loss: 5.2728... Generator Loss: 0.0115
# Epoch 1/2... Discriminator Loss: 4.2688... Generator Loss: 0.0525
# Epoch 1/2... Discriminator Loss: 3.1048... Generator Loss: 0.0460
# Epoch 1/2... Discriminator Loss: 3.2585... Generator Loss: 0.0765
# Epoch 1/2... Discriminator Loss: 4.9842... Generator Loss: 0.0234
# Epoch 1/2... Discriminator Loss: 4.5320... Generator Loss: 0.0895
# Epoch 1/2... Discriminator Loss: 1.8216... Generator Loss: 0.3172
# Epoch 1/2... Discriminator Loss: 0.9227... Generator Loss: 1.9413
# Epoch 1/2... Discriminator Loss: 0.6057... Generator Loss: 2.4269
# Epoch 1/2... Discriminator Loss: 1.0794... Generator Loss: 1.8667
# Epoch 1/2... Discriminator Loss: 1.8416... Generator Loss: 0.1430
# Epoch 1/2... Discriminator Loss: 2.4517... Generator Loss: 0.0928
# Epoch 1/2... Discriminator Loss: 2.3445... Generator Loss: 0.2012
# Epoch 1/2... Discriminator Loss: 1.7466... Generator Loss: 0.2562
# Epoch 1/2... Discriminator Loss: 0.7474... Generator Loss: 0.4226
# Epoch 1/2... Discriminator Loss: 2.7869... Generator Loss: 5.0352
# Epoch 1/2... Discriminator Loss: -0.0040... Generator Loss: 1.1433
# Epoch 1/2... Discriminator Loss: 1.0665... Generator Loss: 1.3304
# Epoch 1/2... Discriminator Loss: 1.3037... Generator Loss: 0.9258
# Epoch 1/2... Discriminator Loss: 0.3955... Generator Loss: 4.7079
# Epoch 1/2... Discriminator Loss: 4.1401... Generator Loss: 5.1906
# Epoch 1/2... Discriminator Loss: 0.9602... Generator Loss: 2.0503
# Epoch 1/2... Discriminator Loss: 1.2653... Generator Loss: 0.9371
# Epoch 1/2... Discriminator Loss: 0.0024... Generator Loss: 1.1203
# Epoch 1/2... Discriminator Loss: 1.5821... Generator Loss: 0.2715
# Epoch 1/2... Discriminator Loss: 3.2386... Generator Loss: 0.1019
# Epoch 1/2... Discriminator Loss: 0.3948... Generator Loss: 1.3025
# Epoch 1/2... Discriminator Loss: -0.0708... Generator Loss: 2.1463
# Epoch 1/2... Discriminator Loss: 0.4795... Generator Loss: 1.6234
# Epoch 1/2... Discriminator Loss: 1.9291... Generator Loss: 4.8046
# Epoch 1/2... Discriminator Loss: -0.8009... Generator Loss: 3.2695
# Epoch 1/2... Discriminator Loss: 2.1649... Generator Loss: 4.2298
# Epoch 1/2... Discriminator Loss: 1.1280... Generator Loss: 1.3581
# Epoch 1/2... Discriminator Loss: 4.6878... Generator Loss: 0.0344
# Epoch 1/2... Discriminator Loss: 2.4791... Generator Loss: 0.0605
# Epoch 1/2... Discriminator Loss: 0.8052... Generator Loss: 0.8741
# Epoch 1/2... Discriminator Loss: 0.2022... Generator Loss: 2.3764
# Epoch 1/2... Discriminator Loss: 2.3004... Generator Loss: 0.1312
# Epoch 1/2... Discriminator Loss: 1.9641... Generator Loss: 0.0516
# Epoch 1/2... Discriminator Loss: 2.4863... Generator Loss: 0.0474
# Epoch 1/2... Discriminator Loss: 3.1852... Generator Loss: 0.0237
# Epoch 1/2... Discriminator Loss: 3.5360... Generator Loss: 0.0385
# Epoch 1/2... Discriminator Loss: 1.4381... Generator Loss: 0.3995
# Epoch 1/2... Discriminator Loss: 2.0066... Generator Loss: 0.2314
# Epoch 1/2... Discriminator Loss: 3.5336... Generator Loss: 0.0320
# Epoch 1/2... Discriminator Loss: 1.9073... Generator Loss: 0.3182
# Epoch 1/2... Discriminator Loss: 2.7085... Generator Loss: 0.0208
# Epoch 1/2... Discriminator Loss: 2.7252... Generator Loss: 0.4654
# Epoch 1/2... Discriminator Loss: 2.3074... Generator Loss: 0.3741
# Epoch 1/2... Discriminator Loss: 2.5744... Generator Loss: 2.8487
# Epoch 1/2... Discriminator Loss: 1.9467... Generator Loss: 2.5988
# Epoch 1/2... Discriminator Loss: 1.9063... Generator Loss: 3.1863
# Epoch 1/2... Discriminator Loss: 1.3162... Generator Loss: 0.6541
# Epoch 1/2... Discriminator Loss: 0.6929... Generator Loss: 1.0072
# Epoch 1/2... Discriminator Loss: 2.2580... Generator Loss: 0.0537
# Epoch 1/2... Discriminator Loss: 2.5559... Generator Loss: 0.1532
# Epoch 1/2... Discriminator Loss: 1.2844... Generator Loss: 0.7980
# Epoch 1/2... Discriminator Loss: 1.8320... Generator Loss: 0.7340
# Epoch 1/2... Discriminator Loss: 2.0191... Generator Loss: 0.1100
# Epoch 1/2... Discriminator Loss: 0.1927... Generator Loss: 1.3383
# Epoch 1/2... Discriminator Loss: 2.1571... Generator Loss: 0.2162
# Epoch 1/2... Discriminator Loss: 2.4025... Generator Loss: 0.5969
# Epoch 1/2... Discriminator Loss: 1.6676... Generator Loss: 2.2440
# Epoch 1/2... Discriminator Loss: 2.1462... Generator Loss: 0.3667
# Epoch 1/2... Discriminator Loss: 2.4323... Generator Loss: 0.1984
# Epoch 1/2... Discriminator Loss: 1.8629... Generator Loss: 0.2111
# Epoch 1/2... Discriminator Loss: 4.4569... Generator Loss: 0.0253
# Epoch 1/2... Discriminator Loss: 4.4227... Generator Loss: 0.0031
# Epoch 1/2... Discriminator Loss: 0.3051... Generator Loss: 0.5674
# Epoch 1/2... Discriminator Loss: 1.9267... Generator Loss: 0.3437
# Epoch 1/2... Discriminator Loss: 0.7905... Generator Loss: 2.8065
# Epoch 1/2... Discriminator Loss: 0.4150... Generator Loss: 1.0365
# Epoch 1/2... Discriminator Loss: 1.4744... Generator Loss: 0.9909
# Epoch 1/2... Discriminator Loss: 3.4509... Generator Loss: 0.0289
# Epoch 1/2... Discriminator Loss: 2.7316... Generator Loss: 0.0834
# Epoch 1/2... Discriminator Loss: 3.8326... Generator Loss: 0.0298
# Epoch 1/2... Discriminator Loss: 3.0433... Generator Loss: 0.1408
# Epoch 1/2... Discriminator Loss: 1.3610... Generator Loss: 0.2616
# Epoch 1/2... Discriminator Loss: 2.2755... Generator Loss: 0.0750
# Epoch 1/2... Discriminator Loss: 1.3500... Generator Loss: 0.4783
# Epoch 1/2... Discriminator Loss: 1.2948... Generator Loss: 0.4691
# Epoch 1/2... Discriminator Loss: 2.0919... Generator Loss: 1.2443
# Epoch 1/2... Discriminator Loss: 2.2693... Generator Loss: 0.2284
# Epoch 1/2... Discriminator Loss: 1.8461... Generator Loss: 0.8803
# Epoch 1/2... Discriminator Loss: 0.9760... Generator Loss: 0.5630
# Epoch 1/2... Discriminator Loss: 1.9082... Generator Loss: 0.2329
# Epoch 1/2... Discriminator Loss: 2.0694... Generator Loss: 0.6152
# Epoch 1/2... Discriminator Loss: 0.6094... Generator Loss: 1.2317
# Epoch 1/2... Discriminator Loss: 1.3159... Generator Loss: 0.8401
# Epoch 1/2... Discriminator Loss: 2.9944... Generator Loss: 3.3787
# Epoch 1/2... Discriminator Loss: 1.4548... Generator Loss: 4.1777
# Epoch 1/2... Discriminator Loss: 0.9390... Generator Loss: 2.1641
# Epoch 1/2... Discriminator Loss: 2.2121... Generator Loss: 0.1045
# Epoch 1/2... Discriminator Loss: 2.2661... Generator Loss: 0.8149
# Epoch 1/2... Discriminator Loss: 0.7408... Generator Loss: 1.2213
# Epoch 1/2... Discriminator Loss: 2.1048... Generator Loss: 0.0995
# Epoch 1/2... Discriminator Loss: 2.9685... Generator Loss: 0.0678
# Epoch 1/2... Discriminator Loss: 2.1129... Generator Loss: 0.1689
# Epoch 1/2... Discriminator Loss: 1.4726... Generator Loss: 0.2975
# Epoch 1/2... Discriminator Loss: 1.9199... Generator Loss: 0.1220
# Epoch 1/2... Discriminator Loss: 1.7697... Generator Loss: 1.4191
# Epoch 1/2... Discriminator Loss: 2.4932... Generator Loss: 3.5102
# Epoch 1/2... Discriminator Loss: 1.7613... Generator Loss: 0.1443
# Epoch 1/2... Discriminator Loss: 4.7339... Generator Loss: 0.0276
# Epoch 1/2... Discriminator Loss: 2.5166... Generator Loss: 0.1572
# Epoch 1/2... Discriminator Loss: 2.2089... Generator Loss: 0.3342
# Epoch 1/2... Discriminator Loss: 2.7847... Generator Loss: 0.0345
# Epoch 1/2... Discriminator Loss: 3.7576... Generator Loss: 0.0244
# Epoch 1/2... Discriminator Loss: 1.5092... Generator Loss: 0.2593
# Epoch 1/2... Discriminator Loss: 2.4648... Generator Loss: 0.0914
# Epoch 1/2... Discriminator Loss: 3.8514... Generator Loss: 0.0385
# Epoch 1/2... Discriminator Loss: 1.0082... Generator Loss: 1.4648
# Epoch 1/2... Discriminator Loss: 3.0267... Generator Loss: 0.2774
# Epoch 1/2... Discriminator Loss: 2.3830... Generator Loss: 0.1345
# Epoch 1/2... Discriminator Loss: 0.7438... Generator Loss: 0.9689
# Epoch 1/2... Discriminator Loss: 3.1726... Generator Loss: 0.1367
# Epoch 1/2... Discriminator Loss: 2.2049... Generator Loss: 0.4933
# Epoch 1/2... Discriminator Loss: 1.9419... Generator Loss: 0.2178
# Epoch 1/2... Discriminator Loss: 1.6859... Generator Loss: 2.9598
# Epoch 1/2... Discriminator Loss: 1.6356... Generator Loss: 4.8981
# Epoch 1/2... Discriminator Loss: 0.8755... Generator Loss: 0.5395
# Epoch 1/2... Discriminator Loss: 1.8912... Generator Loss: 1.1987
# Epoch 1/2... Discriminator Loss: 2.1838... Generator Loss: 0.9130
# Epoch 1/2... Discriminator Loss: 0.8606... Generator Loss: 2.4871
# Epoch 1/2... Discriminator Loss: 1.6438... Generator Loss: 1.2633
# Epoch 1/2... Discriminator Loss: 2.3074... Generator Loss: 1.3552
# Epoch 1/2... Discriminator Loss: 0.2909... Generator Loss: 2.0648
# Epoch 1/2... Discriminator Loss: 2.5889... Generator Loss: 0.1793
# Epoch 1/2... Discriminator Loss: 3.5060... Generator Loss: 0.1587
# Epoch 1/2... Discriminator Loss: 1.9439... Generator Loss: 0.1423
# Epoch 1/2... Discriminator Loss: 1.7753... Generator Loss: 0.3912
# Epoch 1/2... Discriminator Loss: 1.1775... Generator Loss: 0.6719
# Epoch 1/2... Discriminator Loss: 1.2372... Generator Loss: 0.9666
# Epoch 1/2... Discriminator Loss: 2.4895... Generator Loss: 0.1135
# Epoch 1/2... Discriminator Loss: 2.2099... Generator Loss: 0.0612
# Epoch 1/2... Discriminator Loss: 2.8402... Generator Loss: 0.1831
# Epoch 1/2... Discriminator Loss: 3.5032... Generator Loss: 0.0152
# Epoch 1/2... Discriminator Loss: 3.3878... Generator Loss: 0.1395
# Epoch 1/2... Discriminator Loss: 1.7732... Generator Loss: 0.6231
# Epoch 1/2... Discriminator Loss: 1.3249... Generator Loss: 2.7614
# Epoch 1/2... Discriminator Loss: 1.5999... Generator Loss: 0.2140
# Epoch 1/2... Discriminator Loss: 2.5237... Generator Loss: 0.8521
# Epoch 1/2... Discriminator Loss: 4.7851... Generator Loss: 5.9427
# Epoch 1/2... Discriminator Loss: 2.6672... Generator Loss: 0.1762
# Epoch 1/2... Discriminator Loss: 2.1421... Generator Loss: 0.2165
# Epoch 1/2... Discriminator Loss: 3.2650... Generator Loss: 0.0452
# Epoch 1/2... Discriminator Loss: 3.2618... Generator Loss: 0.0657
# Epoch 1/2... Discriminator Loss: 2.0440... Generator Loss: 0.3644
# Epoch 1/2... Discriminator Loss: 2.7107... Generator Loss: 0.1027
# Epoch 1/2... Discriminator Loss: 2.9790... Generator Loss: 0.0485
# Epoch 1/2... Discriminator Loss: 2.1683... Generator Loss: 0.1671
# Epoch 1/2... Discriminator Loss: 0.6053... Generator Loss: 1.6360
# Epoch 1/2... Discriminator Loss: 1.8054... Generator Loss: 2.9806
# Epoch 1/2... Discriminator Loss: 1.6484... Generator Loss: 1.7063
# Epoch 1/2... Discriminator Loss: 3.7229... Generator Loss: 0.0698
# Epoch 1/2... Discriminator Loss: 1.5010... Generator Loss: 0.5539
# Epoch 1/2... Discriminator Loss: 1.3185... Generator Loss: 0.2098
# Epoch 1/2... Discriminator Loss: 1.9175... Generator Loss: 1.1960
# Epoch 1/2... Discriminator Loss: 1.1461... Generator Loss: 1.7902
# Epoch 1/2... Discriminator Loss: 1.3091... Generator Loss: 0.3445
# Epoch 1/2... Discriminator Loss: 2.7828... Generator Loss: 0.0450
# Epoch 1/2... Discriminator Loss: 1.6315... Generator Loss: 1.0053
# Epoch 1/2... Discriminator Loss: 1.7561... Generator Loss: 0.7158
# Epoch 1/2... Discriminator Loss: 1.1493... Generator Loss: 0.9522
# Epoch 1/2... Discriminator Loss: 1.7835... Generator Loss: 0.6601
# Epoch 1/2... Discriminator Loss: 1.8026... Generator Loss: 3.5737
# Epoch 1/2... Discriminator Loss: 1.3975... Generator Loss: 1.0910
# Epoch 1/2... Discriminator Loss: -0.0669... Generator Loss: 1.7829
# Epoch 1/2... Discriminator Loss: 1.1869... Generator Loss: 0.3543
# Epoch 1/2... Discriminator Loss: 1.1894... Generator Loss: 2.1060
# Epoch 1/2... Discriminator Loss: 0.8191... Generator Loss: 1.6547
# Epoch 1/2... Discriminator Loss: 1.0700... Generator Loss: 0.3157
# Epoch 1/2... Discriminator Loss: 6.2226... Generator Loss: 0.0045
# Epoch 1/2... Discriminator Loss: 1.9825... Generator Loss: 0.1131
# Epoch 1/2... Discriminator Loss: 1.6769... Generator Loss: 0.4798
# Epoch 1/2... Discriminator Loss: 2.8558... Generator Loss: 0.3094
# Epoch 1/2... Discriminator Loss: 3.1639... Generator Loss: 0.1272
# Epoch 1/2... Discriminator Loss: 2.2268... Generator Loss: 0.3024
# Epoch 1/2... Discriminator Loss: 1.5918... Generator Loss: 1.1199
# Epoch 1/2... Discriminator Loss: 1.8134... Generator Loss: 2.6257
# Epoch 1/2... Discriminator Loss: 1.5049... Generator Loss: 0.7275
# Epoch 1/2... Discriminator Loss: 2.7145... Generator Loss: 0.0595
# Epoch 1/2... Discriminator Loss: 3.0031... Generator Loss: 0.0646
# Epoch 1/2... Discriminator Loss: 1.7909... Generator Loss: 0.1186
# Epoch 1/2... Discriminator Loss: 1.4222... Generator Loss: 0.3866
# Epoch 1/2... Discriminator Loss: 2.0743... Generator Loss: 0.1805
# Epoch 1/2... Discriminator Loss: 1.4685... Generator Loss: 1.1722
# Epoch 1/2... Discriminator Loss: 1.3100... Generator Loss: 1.2060
# Epoch 1/2... Discriminator Loss: 0.6514... Generator Loss: 2.3771
# Epoch 1/2... Discriminator Loss: 2.9263... Generator Loss: 3.9266
# Epoch 1/2... Discriminator Loss: 0.1904... Generator Loss: 1.6177
# Epoch 1/2... Discriminator Loss: 2.4217... Generator Loss: 0.1525
# Epoch 1/2... Discriminator Loss: 2.3500... Generator Loss: 0.2270
# Epoch 1/2... Discriminator Loss: 2.4546... Generator Loss: 2.6069
# Epoch 1/2... Discriminator Loss: 0.3087... Generator Loss: 0.8852
# Epoch 1/2... Discriminator Loss: 2.9487... Generator Loss: 0.5192
# Epoch 1/2... Discriminator Loss: 2.6337... Generator Loss: 0.5807
# Epoch 1/2... Discriminator Loss: 2.9215... Generator Loss: 2.0441
# Epoch 1/2... Discriminator Loss: 2.1716... Generator Loss: 1.0092
# Epoch 1/2... Discriminator Loss: 2.3132... Generator Loss: 0.1995
# Epoch 1/2... Discriminator Loss: 1.9040... Generator Loss: 0.6306
# Epoch 1/2... Discriminator Loss: 2.5210... Generator Loss: 0.2076
# Epoch 1/2... Discriminator Loss: 2.9273... Generator Loss: 0.1047
# Epoch 1/2... Discriminator Loss: 2.5746... Generator Loss: 0.0623
# Epoch 1/2... Discriminator Loss: 0.0924... Generator Loss: 1.1976
# Epoch 1/2... Discriminator Loss: -0.0383... Generator Loss: 2.7400
# Epoch 1/2... Discriminator Loss: 0.8360... Generator Loss: 1.0305
# Epoch 1/2... Discriminator Loss: 2.0518... Generator Loss: 0.2494
# Epoch 1/2... Discriminator Loss: 3.5869... Generator Loss: 0.0805
# Epoch 1/2... Discriminator Loss: 3.6505... Generator Loss: 0.1904
# Epoch 1/2... Discriminator Loss: 1.7072... Generator Loss: 0.3616
# Epoch 1/2... Discriminator Loss: 1.8817... Generator Loss: 0.5493
# Epoch 1/2... Discriminator Loss: 2.4785... Generator Loss: 2.3561
# Epoch 1/2... Discriminator Loss: 0.0896... Generator Loss: 1.0269
# Epoch 1/2... Discriminator Loss: 1.0946... Generator Loss: 1.2775
# Epoch 1/2... Discriminator Loss: 2.1704... Generator Loss: 0.1972
# Epoch 1/2... Discriminator Loss: 3.0157... Generator Loss: 0.0298
# Epoch 1/2... Discriminator Loss: 1.4056... Generator Loss: 0.2293
# Epoch 1/2... Discriminator Loss: 3.4852... Generator Loss: 0.0705
# Epoch 1/2... Discriminator Loss: 2.7121... Generator Loss: 0.0708
# Epoch 1/2... Discriminator Loss: 3.1018... Generator Loss: 0.2260
# Epoch 1/2... Discriminator Loss: 3.8576... Generator Loss: 0.0796
# Epoch 1/2... Discriminator Loss: 1.4737... Generator Loss: 0.2443
# Epoch 1/2... Discriminator Loss: 3.5124... Generator Loss: 0.0587
# Epoch 1/2... Discriminator Loss: 2.9313... Generator Loss: 0.0415
# Epoch 1/2... Discriminator Loss: 1.6977... Generator Loss: 0.2123
# Epoch 1/2... Discriminator Loss: 1.8094... Generator Loss: 0.1667
# Epoch 1/2... Discriminator Loss: 1.4365... Generator Loss: 0.3969
# Epoch 1/2... Discriminator Loss: 2.5657... Generator Loss: 0.0586
# Epoch 1/2... Discriminator Loss: 0.5230... Generator Loss: 0.5472
# Epoch 1/2... Discriminator Loss: 1.8415... Generator Loss: 0.1695
# Epoch 1/2... Discriminator Loss: 1.5102... Generator Loss: 0.2675
# Epoch 1/2... Discriminator Loss: 0.7103... Generator Loss: 0.6398
# Epoch 1/2... Discriminator Loss: 1.1073... Generator Loss: 0.3574
# Epoch 1/2... Discriminator Loss: 5.8600... Generator Loss: 0.0238
# Epoch 1/2... Discriminator Loss: 4.4734... Generator Loss: 0.0084
# Epoch 1/2... Discriminator Loss: 2.8523... Generator Loss: 0.0354
# Epoch 1/2... Discriminator Loss: 1.4761... Generator Loss: 0.6159
# Epoch 1/2... Discriminator Loss: 0.5184... Generator Loss: 1.4738
# Epoch 1/2... Discriminator Loss: 3.1556... Generator Loss: 0.4395
# Epoch 1/2... Discriminator Loss: 3.7883... Generator Loss: 0.0064
# Epoch 1/2... Discriminator Loss: 2.5600... Generator Loss: 0.0820
# Epoch 1/2... Discriminator Loss: 2.6035... Generator Loss: 0.0901
# Epoch 1/2... Discriminator Loss: 2.0050... Generator Loss: 1.8609
# Epoch 1/2... Discriminator Loss: 0.8722... Generator Loss: 1.2008
# Epoch 1/2... Discriminator Loss: 1.7695... Generator Loss: 0.8540
# Epoch 1/2... Discriminator Loss: 1.7160... Generator Loss: 0.6463
# Epoch 1/2... Discriminator Loss: 1.0124... Generator Loss: 1.4395
# Epoch 1/2... Discriminator Loss: 0.5957... Generator Loss: 0.7289
# Epoch 1/2... Discriminator Loss: 2.0983... Generator Loss: 0.0284
# Epoch 1/2... Discriminator Loss: 4.3819... Generator Loss: 0.0281
# Epoch 1/2... Discriminator Loss: 1.5083... Generator Loss: 1.1292
# Epoch 1/2... Discriminator Loss: 2.4194... Generator Loss: 2.0720
# Epoch 1/2... Discriminator Loss: 1.7830... Generator Loss: 0.6704
# Epoch 1/2... Discriminator Loss: 2.1710... Generator Loss: 2.0233
# Epoch 1/2... Discriminator Loss: 1.0975... Generator Loss: 2.4577
# Epoch 1/2... Discriminator Loss: -0.0088... Generator Loss: 1.9778
# Epoch 1/2... Discriminator Loss: 1.4270... Generator Loss: 0.9922
# Epoch 1/2... Discriminator Loss: 3.6806... Generator Loss: 2.9526
# Epoch 1/2... Discriminator Loss: 0.4790... Generator Loss: 1.4111
# Epoch 1/2... Discriminator Loss: 1.6660... Generator Loss: 0.5613
# Epoch 1/2... Discriminator Loss: 1.9721... Generator Loss: 0.7411
# Epoch 1/2... Discriminator Loss: 3.2601... Generator Loss: 0.0527
# Epoch 1/2... Discriminator Loss: 3.0108... Generator Loss: 0.0144
# Epoch 1/2... Discriminator Loss: 2.9061... Generator Loss: 0.1362
# Epoch 1/2... Discriminator Loss: 1.4046... Generator Loss: 1.6748
# Epoch 1/2... Discriminator Loss: 1.7817... Generator Loss: 2.3570
# Epoch 1/2... Discriminator Loss: 1.8230... Generator Loss: 0.4729
# Epoch 1/2... Discriminator Loss: 1.4359... Generator Loss: 1.3357
# Epoch 1/2... Discriminator Loss: 0.9669... Generator Loss: 1.1894
# Epoch 1/2... Discriminator Loss: 1.3651... Generator Loss: 1.1796
# Epoch 1/2... Discriminator Loss: 4.0817... Generator Loss: 0.0466
# Epoch 1/2... Discriminator Loss: 4.1708... Generator Loss: 0.0316
# Epoch 1/2... Discriminator Loss: 3.8112... Generator Loss: 0.1475
# Epoch 1/2... Discriminator Loss: 2.5315... Generator Loss: 0.5004
# Epoch 1/2... Discriminator Loss: 2.9856... Generator Loss: 0.2056
# Epoch 1/2... Discriminator Loss: 2.4352... Generator Loss: 0.0661
# Epoch 1/2... Discriminator Loss: 3.0277... Generator Loss: 0.0259
# Epoch 1/2... Discriminator Loss: 2.2126... Generator Loss: 0.1288
# Epoch 1/2... Discriminator Loss: 2.9862... Generator Loss: 0.1543
# Epoch 1/2... Discriminator Loss: 1.5078... Generator Loss: 1.6281
# Epoch 1/2... Discriminator Loss: 0.1728... Generator Loss: 0.8872
# Epoch 1/2... Discriminator Loss: 0.4986... Generator Loss: 0.4744
# Epoch 1/2... Discriminator Loss: 3.2972... Generator Loss: 5.6623
# Epoch 1/2... Discriminator Loss: 1.2358... Generator Loss: 0.5965
# Epoch 1/2... Discriminator Loss: 5.1362... Generator Loss: 0.0234
# Epoch 1/2... Discriminator Loss: 0.7724... Generator Loss: 0.8053
# Epoch 1/2... Discriminator Loss: 1.3946... Generator Loss: 0.6970
# Epoch 1/2... Discriminator Loss: 2.0415... Generator Loss: 0.8910
# Epoch 1/2... Discriminator Loss: 2.4646... Generator Loss: 0.2021
# Epoch 1/2... Discriminator Loss: 0.2879... Generator Loss: 1.4328
# Epoch 1/2... Discriminator Loss: 1.4307... Generator Loss: 1.5459
# Epoch 1/2... Discriminator Loss: 2.3128... Generator Loss: 0.1505
# Epoch 1/2... Discriminator Loss: 1.9931... Generator Loss: 0.1866
# Epoch 1/2... Discriminator Loss: 0.9087... Generator Loss: 1.7597
# Epoch 1/2... Discriminator Loss: 1.1055... Generator Loss: 0.9361
# Epoch 1/2... Discriminator Loss: 2.7356... Generator Loss: 2.6975
# Epoch 1/2... Discriminator Loss: 0.6085... Generator Loss: 1.2641
# Epoch 1/2... Discriminator Loss: 4.1861... Generator Loss: 0.0995
# Epoch 1/2... Discriminator Loss: 3.2712... Generator Loss: 0.0334
# Epoch 1/2... Discriminator Loss: 2.3104... Generator Loss: 0.2883
# Epoch 1/2... Discriminator Loss: 1.3688... Generator Loss: 0.7223
# Epoch 1/2... Discriminator Loss: 1.7539... Generator Loss: 0.8494
# Epoch 1/2... Discriminator Loss: 0.8150... Generator Loss: 2.5182
# Epoch 1/2... Discriminator Loss: 0.9173... Generator Loss: 1.2099
# Epoch 1/2... Discriminator Loss: 1.9844... Generator Loss: 1.8513
# Epoch 1/2... Discriminator Loss: 1.1639... Generator Loss: 1.8238
# Epoch 1/2... Discriminator Loss: 0.4199... Generator Loss: 2.8663
# Epoch 1/2... Discriminator Loss: 0.5990... Generator Loss: 0.7360
# Epoch 1/2... Discriminator Loss: 0.8591... Generator Loss: 0.7479
# Epoch 1/2... Discriminator Loss: 1.2211... Generator Loss: 3.0502
# Epoch 1/2... Discriminator Loss: 1.6851... Generator Loss: 1.6736
# Epoch 1/2... Discriminator Loss: 1.8271... Generator Loss: 0.9758
# Epoch 1/2... Discriminator Loss: 2.3894... Generator Loss: 3.1509
# Epoch 1/2... Discriminator Loss: 0.9254... Generator Loss: 1.5872
# Epoch 1/2... Discriminator Loss: 2.1267... Generator Loss: 0.4242
# Epoch 1/2... Discriminator Loss: 2.0463... Generator Loss: 0.2402
# Epoch 1/2... Discriminator Loss: 1.1776... Generator Loss: 0.5132
# Epoch 1/2... Discriminator Loss: 2.5222... Generator Loss: 0.1076
# Epoch 1/2... Discriminator Loss: 2.1996... Generator Loss: 0.3382
# Epoch 1/2... Discriminator Loss: 2.5437... Generator Loss: 3.4667
# Epoch 1/2... Discriminator Loss: 1.4832... Generator Loss: 2.9758
# Epoch 1/2... Discriminator Loss: 0.9515... Generator Loss: 1.0036
# Epoch 1/2... Discriminator Loss: 1.2662... Generator Loss: 1.4133
# Epoch 1/2... Discriminator Loss: -0.2270... Generator Loss: 1.5355
# Epoch 1/2... Discriminator Loss: 1.4714... Generator Loss: 1.1494
# Epoch 1/2... Discriminator Loss: 1.3650... Generator Loss: 1.0562
# Epoch 1/2... Discriminator Loss: 2.7561... Generator Loss: 0.2455
# Epoch 1/2... Discriminator Loss: 3.1437... Generator Loss: 0.1434
# Epoch 1/2... Discriminator Loss: 4.0487... Generator Loss: 0.0568
# Epoch 1/2... Discriminator Loss: 1.5906... Generator Loss: 0.1821
# Epoch 1/2... Discriminator Loss: 2.5888... Generator Loss: 0.1604
# Epoch 1/2... Discriminator Loss: 0.9713... Generator Loss: 0.7939
# Epoch 1/2... Discriminator Loss: 1.6495... Generator Loss: 0.4999
# Epoch 1/2... Discriminator Loss: 1.2366... Generator Loss: 0.3805
# Epoch 1/2... Discriminator Loss: 3.8491... Generator Loss: 0.0780
# Epoch 1/2... Discriminator Loss: 3.6890... Generator Loss: 0.0378
# Epoch 1/2... Discriminator Loss: 2.8952... Generator Loss: 0.1018
# Epoch 1/2... Discriminator Loss: 2.6923... Generator Loss: 0.1793
# Epoch 1/2... Discriminator Loss: 1.2848... Generator Loss: 0.2689
# Epoch 1/2... Discriminator Loss: 2.1886... Generator Loss: 0.4253
# Epoch 1/2... Discriminator Loss: 2.4202... Generator Loss: 0.1569
# Epoch 1/2... Discriminator Loss: 1.5102... Generator Loss: 0.7352
# Epoch 1/2... Discriminator Loss: 0.8366... Generator Loss: 1.1454
# Epoch 1/2... Discriminator Loss: 2.4996... Generator Loss: 2.3286
# Epoch 1/2... Discriminator Loss: 1.6988... Generator Loss: 1.7600
# Epoch 1/2... Discriminator Loss: 0.4739... Generator Loss: 1.1730
# Epoch 1/2... Discriminator Loss: 1.7814... Generator Loss: 0.3135
# Epoch 1/2... Discriminator Loss: 2.4940... Generator Loss: 0.0966
# Epoch 1/2... Discriminator Loss: 2.7803... Generator Loss: 0.0565
# Epoch 1/2... Discriminator Loss: 3.4265... Generator Loss: 0.0358
# Epoch 1/2... Discriminator Loss: 1.3773... Generator Loss: 0.4592
# Epoch 1/2... Discriminator Loss: 0.9917... Generator Loss: 0.3413
# Epoch 1/2... Discriminator Loss: 1.2369... Generator Loss: 1.6401
# Epoch 1/2... Discriminator Loss: 1.1260... Generator Loss: 3.0893
# Epoch 1/2... Discriminator Loss: 1.2468... Generator Loss: 0.5565
# Epoch 1/2... Discriminator Loss: 1.3651... Generator Loss: 3.0547
# Epoch 1/2... Discriminator Loss: 1.5834... Generator Loss: 1.0722
# Epoch 1/2... Discriminator Loss: 0.8363... Generator Loss: 1.5869
# Epoch 1/2... Discriminator Loss: 2.5058... Generator Loss: 0.2096
# Epoch 1/2... Discriminator Loss: 1.6624... Generator Loss: 0.9773
# Epoch 1/2... Discriminator Loss: 1.3032... Generator Loss: 0.6346
# Epoch 1/2... Discriminator Loss: 2.1253... Generator Loss: 0.4851
# Epoch 1/2... Discriminator Loss: 0.2206... Generator Loss: 2.9601
# Epoch 1/2... Discriminator Loss: 1.2042... Generator Loss: 0.5653
# Epoch 1/2... Discriminator Loss: 1.1288... Generator Loss: 1.9449
# Epoch 1/2... Discriminator Loss: 1.9083... Generator Loss: 1.1136
# Epoch 1/2... Discriminator Loss: 2.0777... Generator Loss: 0.1593
# Epoch 1/2... Discriminator Loss: 4.7188... Generator Loss: 0.0070
# Epoch 1/2... Discriminator Loss: 4.1141... Generator Loss: 0.0159
# Epoch 1/2... Discriminator Loss: 0.9490... Generator Loss: 0.8910
# Epoch 1/2... Discriminator Loss: 3.1367... Generator Loss: 0.0893
# Epoch 1/2... Discriminator Loss: 1.5345... Generator Loss: 0.1992
# Epoch 1/2... Discriminator Loss: 1.3131... Generator Loss: 0.8721
# Epoch 1/2... Discriminator Loss: 0.9014... Generator Loss: 2.6127
# Epoch 1/2... Discriminator Loss: 2.2392... Generator Loss: 0.3472
# Epoch 1/2... Discriminator Loss: 5.0270... Generator Loss: 0.2103
# Epoch 1/2... Discriminator Loss: 3.2543... Generator Loss: 0.0422
# Epoch 1/2... Discriminator Loss: 3.0612... Generator Loss: 0.0392
# Epoch 1/2... Discriminator Loss: 3.4039... Generator Loss: 0.1878
# Epoch 1/2... Discriminator Loss: 1.1023... Generator Loss: 0.7630
# Epoch 1/2... Discriminator Loss: 1.3670... Generator Loss: 0.2977
# Epoch 1/2... Discriminator Loss: 0.6699... Generator Loss: 0.7697
# Epoch 1/2... Discriminator Loss: 0.7367... Generator Loss: 1.2753
# Epoch 1/2... Discriminator Loss: 1.7621... Generator Loss: 0.0973
# Epoch 1/2... Discriminator Loss: 2.2080... Generator Loss: 0.0889
# Epoch 1/2... Discriminator Loss: 1.7396... Generator Loss: 0.2933
# Epoch 1/2... Discriminator Loss: 2.1765... Generator Loss: 0.4818
# Epoch 1/2... Discriminator Loss: 2.0002... Generator Loss: 2.5923
# Epoch 1/2... Discriminator Loss: 0.3987... Generator Loss: 1.1349
# Epoch 1/2... Discriminator Loss: 1.4347... Generator Loss: 0.5580
# Epoch 1/2... Discriminator Loss: 2.3991... Generator Loss: 0.1612
# Epoch 1/2... Discriminator Loss: 1.6161... Generator Loss: 0.2718
# Epoch 1/2... Discriminator Loss: 4.0573... Generator Loss: 0.0486
# Epoch 1/2... Discriminator Loss: 2.5736... Generator Loss: 0.2700
# Epoch 1/2... Discriminator Loss: 2.3200... Generator Loss: 0.1472
# Epoch 1/2... Discriminator Loss: 1.6442... Generator Loss: 0.3166
# Epoch 1/2... Discriminator Loss: 3.8972... Generator Loss: 0.0328
# Epoch 1/2... Discriminator Loss: 2.4657... Generator Loss: 0.0243
# Epoch 1/2... Discriminator Loss: 1.6537... Generator Loss: 1.2182
# Epoch 1/2... Discriminator Loss: 1.2167... Generator Loss: 0.2432
# Epoch 1/2... Discriminator Loss: 1.1401... Generator Loss: 0.5216
# Epoch 1/2... Discriminator Loss: 1.1793... Generator Loss: 1.3565
# Epoch 1/2... Discriminator Loss: 1.5207... Generator Loss: 0.7272
# Epoch 1/2... Discriminator Loss: 1.9557... Generator Loss: 0.6373
# Epoch 1/2... Discriminator Loss: 1.2300... Generator Loss: 1.5257
# Epoch 1/2... Discriminator Loss: 3.3141... Generator Loss: 0.0732
# Epoch 1/2... Discriminator Loss: 2.4515... Generator Loss: 0.2663
# Epoch 1/2... Discriminator Loss: 5.1229... Generator Loss: 0.0722
# Epoch 1/2... Discriminator Loss: 1.6879... Generator Loss: 0.2421
# Epoch 1/2... Discriminator Loss: 2.1319... Generator Loss: 0.2554
# Epoch 1/2... Discriminator Loss: 1.6291... Generator Loss: 0.6832
# Epoch 1/2... Discriminator Loss: 3.6686... Generator Loss: 0.1347
# Epoch 1/2... Discriminator Loss: 2.9308... Generator Loss: 0.3060
# Epoch 1/2... Discriminator Loss: 2.4450... Generator Loss: 0.0453
# Epoch 1/2... Discriminator Loss: 1.7326... Generator Loss: 0.1272
# Epoch 1/2... Discriminator Loss: 2.6936... Generator Loss: 0.2598
# Epoch 1/2... Discriminator Loss: 2.3493... Generator Loss: 0.2999
# Epoch 1/2... Discriminator Loss: 2.8482... Generator Loss: 0.0779
# Epoch 1/2... Discriminator Loss: 2.9435... Generator Loss: 0.1123
# Epoch 1/2... Discriminator Loss: 1.5090... Generator Loss: 0.5833
# Epoch 1/2... Discriminator Loss: 1.6244... Generator Loss: 2.2746
# Epoch 1/2... Discriminator Loss: 2.3198... Generator Loss: 0.2284
# Epoch 1/2... Discriminator Loss: 2.9447... Generator Loss: 0.0824
# Epoch 1/2... Discriminator Loss: 1.9636... Generator Loss: 0.6605
# Epoch 1/2... Discriminator Loss: 1.1540... Generator Loss: 3.6251
# Epoch 1/2... Discriminator Loss: 2.4072... Generator Loss: 0.2414
# Epoch 1/2... Discriminator Loss: 1.7401... Generator Loss: 0.1395
# Epoch 1/2... Discriminator Loss: 1.5093... Generator Loss: 0.2533
# Epoch 1/2... Discriminator Loss: 0.9976... Generator Loss: 0.7577
# Epoch 1/2... Discriminator Loss: 0.6598... Generator Loss: 0.9904
# Epoch 1/2... Discriminator Loss: 1.2410... Generator Loss: 0.4665
# Epoch 1/2... Discriminator Loss: 1.5684... Generator Loss: 0.2375
# Epoch 1/2... Discriminator Loss: 2.2056... Generator Loss: 0.3275
# Epoch 1/2... Discriminator Loss: 0.7906... Generator Loss: 1.5118
# Epoch 1/2... Discriminator Loss: 1.2929... Generator Loss: 0.7224
# Epoch 1/2... Discriminator Loss: 1.9063... Generator Loss: 0.2075
# Epoch 1/2... Discriminator Loss: 1.6182... Generator Loss: 0.8075
# Epoch 1/2... Discriminator Loss: 1.1468... Generator Loss: 1.4702
# Epoch 1/2... Discriminator Loss: 1.8488... Generator Loss: 1.4772
# Epoch 1/2... Discriminator Loss: 1.1717... Generator Loss: 1.9315
# Epoch 1/2... Discriminator Loss: 3.2388... Generator Loss: 3.3625
# Epoch 1/2... Discriminator Loss: 1.8467... Generator Loss: 2.0693
# Epoch 1/2... Discriminator Loss: 0.0133... Generator Loss: 1.7896
# Epoch 1/2... Discriminator Loss: 2.4898... Generator Loss: 0.1820
# Epoch 1/2... Discriminator Loss: 2.5379... Generator Loss: 0.0963
# Epoch 1/2... Discriminator Loss: 3.8680... Generator Loss: 0.0358
# Epoch 1/2... Discriminator Loss: 2.7904... Generator Loss: 1.1165
# Epoch 1/2... Discriminator Loss: 1.3904... Generator Loss: 0.8397
# Epoch 1/2... Discriminator Loss: 0.5376... Generator Loss: 1.0501
# Epoch 1/2... Discriminator Loss: 0.9349... Generator Loss: 2.8158
# Epoch 1/2... Discriminator Loss: 0.7800... Generator Loss: 1.1768
# Epoch 1/2... Discriminator Loss: 4.2863... Generator Loss: 0.0183
# Epoch 1/2... Discriminator Loss: 3.6889... Generator Loss: 0.0221
# Epoch 1/2... Discriminator Loss: 0.9691... Generator Loss: 1.4567
# Epoch 1/2... Discriminator Loss: 1.4018... Generator Loss: 0.7977
# Epoch 1/2... Discriminator Loss: 0.5453... Generator Loss: 0.7431
# Epoch 1/2... Discriminator Loss: 2.9007... Generator Loss: 0.0441
# Epoch 1/2... Discriminator Loss: 2.7314... Generator Loss: 0.1040
# Epoch 1/2... Discriminator Loss: 0.5506... Generator Loss: 1.4441
# Epoch 1/2... Discriminator Loss: -0.1302... Generator Loss: 0.9781
# Epoch 1/2... Discriminator Loss: 1.0756... Generator Loss: 1.1660
# Epoch 1/2... Discriminator Loss: 0.4447... Generator Loss: 1.5390
# Epoch 1/2... Discriminator Loss: 3.0399... Generator Loss: 0.5765
# Epoch 1/2... Discriminator Loss: 3.6408... Generator Loss: 0.0108
# Epoch 1/2... Discriminator Loss: 2.7743... Generator Loss: 0.2545
# Epoch 1/2... Discriminator Loss: 3.8434... Generator Loss: 0.0178
# Epoch 1/2... Discriminator Loss: 1.6097... Generator Loss: 0.2079
# Epoch 1/2... Discriminator Loss: 1.6281... Generator Loss: 0.2413
# Epoch 1/2... Discriminator Loss: 1.9529... Generator Loss: 0.3889
# Epoch 1/2... Discriminator Loss: 4.4124... Generator Loss: 0.0351
# Epoch 1/2... Discriminator Loss: 0.8576... Generator Loss: 0.8004
# Epoch 1/2... Discriminator Loss: -0.2924... Generator Loss: 1.5270
# Epoch 1/2... Discriminator Loss: 2.5145... Generator Loss: 0.1069
# Epoch 1/2... Discriminator Loss: 2.5577... Generator Loss: 0.1560
# Epoch 1/2... Discriminator Loss: 3.1677... Generator Loss: 0.0207
# Epoch 1/2... Discriminator Loss: 1.5637... Generator Loss: 2.0251
# Epoch 1/2... Discriminator Loss: 0.1448... Generator Loss: 2.1030
# Epoch 1/2... Discriminator Loss: 2.3726... Generator Loss: 0.0714
# Epoch 1/2... Discriminator Loss: 3.5577... Generator Loss: 0.0392
# Epoch 1/2... Discriminator Loss: 2.6573... Generator Loss: 0.2286
# Epoch 1/2... Discriminator Loss: 2.8928... Generator Loss: 0.6753
# ...
# Epoch 2/2... Discriminator Loss: -15.7973... Generator Loss: 3.2920
# Epoch 2/2... Discriminator Loss: 105.1943... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -7.2956... Generator Loss: 1.1457
# Epoch 2/2... Discriminator Loss: 39.6062... Generator Loss: 156.9118
# Epoch 2/2... Discriminator Loss: 77.5561... Generator Loss: 2.5602
# Epoch 2/2... Discriminator Loss: 98.3010... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 4.9870... Generator Loss: 107.8181
# Epoch 2/2... Discriminator Loss: 19.2494... Generator Loss: 0.2261
# Epoch 2/2... Discriminator Loss: 86.5168... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -16.3562... Generator Loss: 5.8910
# Epoch 2/2... Discriminator Loss: 22.8285... Generator Loss: 142.3277
# Epoch 2/2... Discriminator Loss: 13.8222... Generator Loss: 0.0001
# Epoch 2/2... Discriminator Loss: 9.6625... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 35.3807... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -40.2764... Generator Loss: 35.5937
# Epoch 2/2... Discriminator Loss: -18.4339... Generator Loss: 53.1901
# Epoch 2/2... Discriminator Loss: 58.3251... Generator Loss: 0.2728
# Epoch 2/2... Discriminator Loss: -4.9694... Generator Loss: 1.0609
# Epoch 2/2... Discriminator Loss: -28.1127... Generator Loss: 43.1061
# Epoch 2/2... Discriminator Loss: 44.7142... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -12.5422... Generator Loss: 15.0988
# Epoch 2/2... Discriminator Loss: -7.4444... Generator Loss: 2.6361
# Epoch 2/2... Discriminator Loss: -34.2913... Generator Loss: 10.1194
# Epoch 2/2... Discriminator Loss: 22.0455... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -3.3648... Generator Loss: 7.0457
# Epoch 2/2... Discriminator Loss: -11.8253... Generator Loss: 6.1549
# Epoch 2/2... Discriminator Loss: -4.7372... Generator Loss: 88.8369
# Epoch 2/2... Discriminator Loss: 61.3218... Generator Loss: 1.4057
# Epoch 2/2... Discriminator Loss: 120.9771... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 94.8439... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 105.6623... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -3.1704... Generator Loss: 2.2723
# Epoch 2/2... Discriminator Loss: -13.0659... Generator Loss: 24.2662
# Epoch 2/2... Discriminator Loss: 32.5204... Generator Loss: 2.2167
# Epoch 2/2... Discriminator Loss: -7.3834... Generator Loss: 0.5977
# Epoch 2/2... Discriminator Loss: 31.0179... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -62.3048... Generator Loss: 68.8488
# Epoch 2/2... Discriminator Loss: -30.0398... Generator Loss: 10.9735
# Epoch 2/2... Discriminator Loss: -42.1284... Generator Loss: 138.0311
# Epoch 2/2... Discriminator Loss: -30.1081... Generator Loss: 12.9247
# Epoch 2/2... Discriminator Loss: 7.5644... Generator Loss: 75.8966
# Epoch 2/2... Discriminator Loss: 78.5499... Generator Loss: 0.0007
# Epoch 2/2... Discriminator Loss: 22.4296... Generator Loss: 0.0306
# Epoch 2/2... Discriminator Loss: -20.1683... Generator Loss: 8.7959
# Epoch 2/2... Discriminator Loss: -39.6393... Generator Loss: 2.4219
# Epoch 2/2... Discriminator Loss: 98.5581... Generator Loss: 0.5245
# Epoch 2/2... Discriminator Loss: -21.8575... Generator Loss: 6.3662
# Epoch 2/2... Discriminator Loss: 59.5156... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -54.4646... Generator Loss: 20.3254
# Epoch 2/2... Discriminator Loss: -26.8812... Generator Loss: 21.2177
# Epoch 2/2... Discriminator Loss: -32.6852... Generator Loss: 126.8404
# Epoch 2/2... Discriminator Loss: -77.9114... Generator Loss: 17.3531
# Epoch 2/2... Discriminator Loss: -21.8951... Generator Loss: 160.5526
# Epoch 2/2... Discriminator Loss: 55.6340... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -31.8754... Generator Loss: 56.0732
# Epoch 2/2... Discriminator Loss: 2.5426... Generator Loss: 2.3547
# Epoch 2/2... Discriminator Loss: 28.8053... Generator Loss: 1.0073
# Epoch 2/2... Discriminator Loss: -38.9481... Generator Loss: 63.2919
# Epoch 2/2... Discriminator Loss: 122.4474... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 39.7074... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 44.7259... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 15.8531... Generator Loss: 7.7254
# Epoch 2/2... Discriminator Loss: 8.3383... Generator Loss: 138.3414
# Epoch 2/2... Discriminator Loss: -19.7638... Generator Loss: 8.5966
# Epoch 2/2... Discriminator Loss: -37.0305... Generator Loss: 82.3961
# Epoch 2/2... Discriminator Loss: -73.8342... Generator Loss: 80.2193
# Epoch 2/2... Discriminator Loss: -33.6209... Generator Loss: 49.3497
# Epoch 2/2... Discriminator Loss: 74.5856... Generator Loss: 0.3878
# Epoch 2/2... Discriminator Loss: -32.5635... Generator Loss: 39.9503
# Epoch 2/2... Discriminator Loss: 140.9085... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 11.3432... Generator Loss: 0.8352
# Epoch 2/2... Discriminator Loss: 89.5167... Generator Loss: 194.4259
# Epoch 2/2... Discriminator Loss: -5.7346... Generator Loss: 12.6862
# Epoch 2/2... Discriminator Loss: 27.7223... Generator Loss: 2.7698
# Epoch 2/2... Discriminator Loss: 23.5896... Generator Loss: 0.5534
# Epoch 2/2... Discriminator Loss: -30.4837... Generator Loss: 6.1237
# Epoch 2/2... Discriminator Loss: -14.5032... Generator Loss: 22.1661
# Epoch 2/2... Discriminator Loss: -10.0584... Generator Loss: 12.9284
# Epoch 2/2... Discriminator Loss: 19.2833... Generator Loss: 0.0003
# Epoch 2/2... Discriminator Loss: -27.5402... Generator Loss: 25.0166
# Epoch 2/2... Discriminator Loss: -53.3340... Generator Loss: 12.0249
# Epoch 2/2... Discriminator Loss: -17.8172... Generator Loss: 0.4959
# Epoch 2/2... Discriminator Loss: -54.7554... Generator Loss: 33.2931
# Epoch 2/2... Discriminator Loss: -53.2913... Generator Loss: 40.8650
# Epoch 2/2... Discriminator Loss: 11.8048... Generator Loss: 11.8985
# Epoch 2/2... Discriminator Loss: 45.6818... Generator Loss: 0.4344
# Epoch 2/2... Discriminator Loss: -1.0424... Generator Loss: 9.2477
# Epoch 2/2... Discriminator Loss: -18.0122... Generator Loss: 1.6384
# Epoch 2/2... Discriminator Loss: -22.5658... Generator Loss: 0.9230
# Epoch 2/2... Discriminator Loss: 113.8357... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 1.6954... Generator Loss: 21.2463
# Epoch 2/2... Discriminator Loss: -0.9613... Generator Loss: 5.7405
# Epoch 2/2... Discriminator Loss: -15.0140... Generator Loss: 3.1132
# Epoch 2/2... Discriminator Loss: -5.5194... Generator Loss: 4.7415
# Epoch 2/2... Discriminator Loss: -76.8949... Generator Loss: 38.8259
# Epoch 2/2... Discriminator Loss: 79.6867... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -1.3838... Generator Loss: 10.6219
# Epoch 2/2... Discriminator Loss: -6.1780... Generator Loss: 11.4467
# Epoch 2/2... Discriminator Loss: 6.5301... Generator Loss: 6.0581
# Epoch 2/2... Discriminator Loss: -6.0495... Generator Loss: 7.6019
# Epoch 2/2... Discriminator Loss: -1.3266... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -16.6321... Generator Loss: 5.8026
# Epoch 2/2... Discriminator Loss: -22.2288... Generator Loss: 5.0443
# Epoch 2/2... Discriminator Loss: -11.1335... Generator Loss: 6.4563
# Epoch 2/2... Discriminator Loss: 16.2430... Generator Loss: 134.6729
# Epoch 2/2... Discriminator Loss: -3.7685... Generator Loss: 0.7394
# Epoch 2/2... Discriminator Loss: 20.7207... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -54.0954... Generator Loss: 49.9737
# Epoch 2/2... Discriminator Loss: 4.9791... Generator Loss: 205.5287
# Epoch 2/2... Discriminator Loss: 51.9109... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -4.7039... Generator Loss: 8.3187
# Epoch 2/2... Discriminator Loss: 36.5594... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 36.2698... Generator Loss: 203.4389
# Epoch 2/2... Discriminator Loss: 50.1517... Generator Loss: 0.0007
# Epoch 2/2... Discriminator Loss: -28.0467... Generator Loss: 5.3229
# Epoch 2/2... Discriminator Loss: -7.8973... Generator Loss: 1.5303
# Epoch 2/2... Discriminator Loss: -14.3720... Generator Loss: 99.8462
# Epoch 2/2... Discriminator Loss: -35.9560... Generator Loss: 58.0354
# Epoch 2/2... Discriminator Loss: 95.9158... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 10.9634... Generator Loss: 201.3590
# Epoch 2/2... Discriminator Loss: 4.2350... Generator Loss: 7.2519
# Epoch 2/2... Discriminator Loss: -21.4848... Generator Loss: 9.6282
# Epoch 2/2... Discriminator Loss: -46.3790... Generator Loss: 75.9318
# Epoch 2/2... Discriminator Loss: 64.5012... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 11.9088... Generator Loss: 4.7721
# Epoch 2/2... Discriminator Loss: -21.9273... Generator Loss: 56.6119
# Epoch 2/2... Discriminator Loss: -2.2125... Generator Loss: 42.9585
# Epoch 2/2... Discriminator Loss: 160.7202... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -6.8719... Generator Loss: 4.4349
# Epoch 2/2... Discriminator Loss: -30.0217... Generator Loss: 9.4229
# Epoch 2/2... Discriminator Loss: -30.8195... Generator Loss: 28.6117
# Epoch 2/2... Discriminator Loss: -16.9978... Generator Loss: 3.7372
# Epoch 2/2... Discriminator Loss: 3.4982... Generator Loss: 214.9405
# Epoch 2/2... Discriminator Loss: -15.1320... Generator Loss: 18.7814
# Epoch 2/2... Discriminator Loss: 25.3934... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 25.9361... Generator Loss: 188.9165
# Epoch 2/2... Discriminator Loss: 6.2672... Generator Loss: 0.8132
# Epoch 2/2... Discriminator Loss: 20.5308... Generator Loss: 0.1622
# Epoch 2/2... Discriminator Loss: -13.4079... Generator Loss: 8.6626
# Epoch 2/2... Discriminator Loss: -22.6258... Generator Loss: 23.3324
# Epoch 2/2... Discriminator Loss: 46.0460... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 88.8123... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -44.6938... Generator Loss: 10.7172
# Epoch 2/2... Discriminator Loss: 142.4646... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 144.0542... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -37.9609... Generator Loss: 36.0479
# Epoch 2/2... Discriminator Loss: 155.1575... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 74.5400... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 0.2595... Generator Loss: 82.2444
# Epoch 2/2... Discriminator Loss: 11.5380... Generator Loss: 0.4706
# Epoch 2/2... Discriminator Loss: 51.7527... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -51.8626... Generator Loss: 32.5083
# Epoch 2/2... Discriminator Loss: -15.9691... Generator Loss: 7.1885
# Epoch 2/2... Discriminator Loss: 35.0637... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 28.7668... Generator Loss: 159.1078
# Epoch 2/2... Discriminator Loss: 20.5750... Generator Loss: 0.0047
# Epoch 2/2... Discriminator Loss: -2.8225... Generator Loss: 4.2340
# Epoch 2/2... Discriminator Loss: 40.1502... Generator Loss: 0.0001
# Epoch 2/2... Discriminator Loss: 29.1433... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 98.6184... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -43.1493... Generator Loss: 25.9752
# Epoch 2/2... Discriminator Loss: -20.3881... Generator Loss: 116.6915
# Epoch 2/2... Discriminator Loss: 90.4880... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 17.0900... Generator Loss: 49.7967
# Epoch 2/2... Discriminator Loss: 8.4370... Generator Loss: 2.3591
# Epoch 2/2... Discriminator Loss: 0.8285... Generator Loss: 9.4140
# Epoch 2/2... Discriminator Loss: 8.3995... Generator Loss: 0.7761
# Epoch 2/2... Discriminator Loss: -1.1599... Generator Loss: 18.6664
# Epoch 2/2... Discriminator Loss: 5.2179... Generator Loss: 3.1814
# Epoch 2/2... Discriminator Loss: -2.7661... Generator Loss: 2.3539
# Epoch 2/2... Discriminator Loss: -3.6425... Generator Loss: 12.1221
# Epoch 2/2... Discriminator Loss: -0.3985... Generator Loss: 4.6143
# Epoch 2/2... Discriminator Loss: -6.9043... Generator Loss: 5.9321
# Epoch 2/2... Discriminator Loss: 17.5354... Generator Loss: 0.0051
# Epoch 2/2... Discriminator Loss: 5.1668... Generator Loss: 2.2838
# Epoch 2/2... Discriminator Loss: -43.3066... Generator Loss: 22.2128
# Epoch 2/2... Discriminator Loss: 45.7045... Generator Loss: 2.8290
# Epoch 2/2... Discriminator Loss: -28.7546... Generator Loss: 113.6392
# Epoch 2/2... Discriminator Loss: -77.2156... Generator Loss: 51.0590
# Epoch 2/2... Discriminator Loss: -44.6797... Generator Loss: 130.8103
# Epoch 2/2... Discriminator Loss: 93.2958... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 95.4202... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -52.5387... Generator Loss: 57.1448
# Epoch 2/2... Discriminator Loss: 11.9408... Generator Loss: 2.0011
# Epoch 2/2... Discriminator Loss: 100.3889... Generator Loss: 171.3770
# Epoch 2/2... Discriminator Loss: 3.8825... Generator Loss: 5.0000
# Epoch 2/2... Discriminator Loss: -1.2932... Generator Loss: 4.6276
# Epoch 2/2... Discriminator Loss: 7.3139... Generator Loss: 1.2614
# Epoch 2/2... Discriminator Loss: 8.4816... Generator Loss: 3.5129
# Epoch 2/2... Discriminator Loss: 113.5462... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -32.9757... Generator Loss: 12.5658
# Epoch 2/2... Discriminator Loss: -1.8430... Generator Loss: 117.3749
# Epoch 2/2... Discriminator Loss: 42.5486... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -22.6552... Generator Loss: 48.8006
# Epoch 2/2... Discriminator Loss: -28.7819... Generator Loss: 1.8091
# Epoch 2/2... Discriminator Loss: -5.5998... Generator Loss: 136.0724
# Epoch 2/2... Discriminator Loss: 35.1474... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -50.2424... Generator Loss: 22.2138
# Epoch 2/2... Discriminator Loss: 140.2584... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 84.3447... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -72.1710... Generator Loss: 42.5310
# Epoch 2/2... Discriminator Loss: 102.3887... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -35.0450... Generator Loss: 44.9548
# Epoch 2/2... Discriminator Loss: 141.7787... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -64.6113... Generator Loss: 53.7894
# Epoch 2/2... Discriminator Loss: 25.3755... Generator Loss: 204.2124
# Epoch 2/2... Discriminator Loss: -21.5989... Generator Loss: 23.0798
# Epoch 2/2... Discriminator Loss: 98.5293... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 42.9624... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -27.0301... Generator Loss: 34.7444
# Epoch 2/2... Discriminator Loss: 81.2206... Generator Loss: 1.6426
# Epoch 2/2... Discriminator Loss: -16.3297... Generator Loss: 0.0039
# Epoch 2/2... Discriminator Loss: 21.6970... Generator Loss: 125.6271
# Epoch 2/2... Discriminator Loss: -6.2312... Generator Loss: 4.6538
# Epoch 2/2... Discriminator Loss: 147.8184... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: 3.1228... Generator Loss: 35.7016
# Epoch 2/2... Discriminator Loss: -5.7029... Generator Loss: 6.3511
# Epoch 2/2... Discriminator Loss: -1.4272... Generator Loss: 1.8688
# Epoch 2/2... Discriminator Loss: -6.6321... Generator Loss: 16.0889
# Epoch 2/2... Discriminator Loss: 39.8210... Generator Loss: 7.7976
# Epoch 2/2... Discriminator Loss: -25.5702... Generator Loss: 51.2141
# Epoch 2/2... Discriminator Loss: 10.6370... Generator Loss: 2.6724
# Epoch 2/2... Discriminator Loss: -47.3843... Generator Loss: 50.3986
# Epoch 2/2... Discriminator Loss: -38.5162... Generator Loss: 6.8666
# Epoch 2/2... Discriminator Loss: -17.4809... Generator Loss: 5.7011
# Epoch 2/2... Discriminator Loss: 65.6088... Generator Loss: 171.7272
# Epoch 2/2... Discriminator Loss: -5.8129... Generator Loss: 11.0465
# Epoch 2/2... Discriminator Loss: 1.3348... Generator Loss: 1.5748
# Epoch 2/2... Discriminator Loss: -11.8878... Generator Loss: 10.5630
# Epoch 2/2... Discriminator Loss: -12.0679... Generator Loss: 25.4526
# Epoch 2/2... Discriminator Loss: -6.0917... Generator Loss: 5.8731
# Epoch 2/2... Discriminator Loss: -25.4354... Generator Loss: 7.2196
# Epoch 2/2... Discriminator Loss: -44.0530... Generator Loss: 15.7753
# Epoch 2/2... Discriminator Loss: 12.9074... Generator Loss: 0.0000
# Epoch 2/2... Discriminator Loss: -49.6753... Generator Loss: 60.7203

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 250
learning_rate = 0.0004
beta1 = 0.2



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 4.5377... Generator Loss: 22.6490
# Epoch 1/1... Discriminator Loss: 1.0499... Generator Loss: 21.1121
# Epoch 1/1... Discriminator Loss: 0.4860... Generator Loss: 14.1389
# Epoch 1/1... Discriminator Loss: 7.8355... Generator Loss: 31.8166
# Epoch 1/1... Discriminator Loss: 1.2640... Generator Loss: 13.0952
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-7eadbd124921> in <module>()
#      14 with tf.Graph().as_default():
#      15     train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
# ---> 16           celeba_dataset.shape, celeba_dataset.image_mode)
#
# <ipython-input-13-dd617a66e25a> in train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode)
#      24         for epoch_i in range(epoch_count):
#      25
# ---> 26             for batch_images in get_batches(batch_size):
#      27                 steps += 1
#      28
#
# D:\Projects\2017-01-27-Neural_Networks\Project 5\face_generation\helper.py in get_batches(self, batch_size)
#     213                 self.data_files[current_index:current_index + batch_size],
#     214                 *self.shape[1:3],
# --> 215                 self.image_mode)
#     216
#     217             current_index += batch_size
#
# D:\Projects\2017-01-27-Neural_Networks\Project 5\face_generation\helper.py in get_batch(image_files, width, height, mode)
#      86 def get_batch(image_files, width, height, mode):
#      87     data_batch = np.array(
# ---> 88         [get_image(sample_file, width, height, mode) for sample_file in image_files]).astype(np.float32)
#      89
#      90     # Make sure the images are in 4 dimensions
#
# D:\Projects\2017-01-27-Neural_Networks\Project 5\face_generation\helper.py in <listcomp>(.0)
#      86 def get_batch(image_files, width, height, mode):
#      87     data_batch = np.array(
# ---> 88         [get_image(sample_file, width, height, mode) for sample_file in image_files]).astype(np.float32)
#      89
#      90     # Make sure the images are in 4 dimensions
#
# D:\Projects\2017-01-27-Neural_Networks\Project 5\face_generation\helper.py in get_image(image_path, width, height, mode)
#      78         j = (image.size[0] - face_width) // 2
#      79         i = (image.size[1] - face_height) // 2
# ---> 80         image = image.crop([j, i, j + face_width, i + face_height])
#      81         image = image.resize([width, height], Image.BILINEAR)
#      82
#
# C:\Program Files\Anaconda3\envs\tensorflow-cpu\lib\site-packages\PIL\Image.py in crop(self, box)
#    1039         """
#    1040
# -> 1041         self.load()
#    1042         if box is None:
#    1043             return self.copy()
#
# C:\Program Files\Anaconda3\envs\tensorflow-cpu\lib\site-packages\PIL\ImageFile.py in load(self)
#     232
#     233                         b = b + s
# --> 234                         n, err_code = decoder.decode(b)
#     235                         if n < 0:
#     236                             break
#
# KeyboardInterrupt:

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
